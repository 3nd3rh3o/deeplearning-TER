# %%
# %pip install tfds
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 0.1 Requires-Python >=3.11,<3.13; 0.2 Requires-Python >=3.11,<3.13; 0.3 Requires-Python >=3.11,<3.13
# ERROR: Could not find a version that satisfies the requirement tfds (from versions: none)
# ERROR: No matching distribution found for tfds

# %% [markdown]
# # Imports

# %%
# Suppression des avertissements liés à Scikit-learn
import warnings  # Masquer les avertissements (ex. : FutureWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# Librairies générales
import pandas as pd  # Librairie pour la manipulation de données
import numpy as np  # Librairie pour le calcul numérique
import sys  # Fonctions et variables liées à l'interpréteur Python
import copy  # Création de copies d'objets
from numpy import mean, std  # Fonctions de calcul de moyenne et d'écart type
import zipfile  # Traitement de fichiers zip
import os  # Manipulation de fichiers et chemins

# Librairie affichage
import matplotlib.pyplot as plt  # Outils de visualisation 2D
from matplotlib import pyplot  # Interface de la bibliothèque Matplotlib
import seaborn as sns  # Bibliothèque de visualisation de données basée sur Matplotlib

# Scikit-learn pour l'évaluation des modèles
from sklearn.metrics import confusion_matrix  # Matrice de confusion
from sklearn.model_selection import KFold  # Outils de validation croisée
from sklearn.metrics import accuracy_score  # Calcul de l'accuracy
from sklearn.model_selection import train_test_split  # Découpage train/test

# TensorFlow et Keras
import tensorflow as tf  # Librairie de deep learning
import keras  # API haut niveau pour construire et entraîner des modèles de deep learning
from keras import layers  # Modules de couches pour construire des modèles Keras
from keras import models  # Outils pour créer des modèles Keras
from keras import optimizers  # Outils d'optimisation
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Générateur d'images pour l'augmentation des données
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping  # Rappels pour le suivi et l'arrêt précoce
from keras.layers import Input, Dense, Dropout, Flatten, Lambda  # Types de couches Keras
from keras.layers import Conv2D, MaxPooling2D  # Couches convolutionnelles et de pooling
from keras.preprocessing import image  # Outils de prétraitement d'images
from tensorflow.keras.models import Model, load_model  # Définition / chargement de modèles
from keras.datasets import fashion_mnist  # Jeu de données Fashion MNIST
from tensorflow.keras.utils import to_categorical  # Conversion en encodage one-hot
from tensorflow.keras.optimizers import SGD  # Optimiseur Stochastic Gradient Descent
from tensorflow.keras.applications.resnet50 import ResNet50  # Modèle ResNet50 pré-entraîné
from tensorflow.keras.preprocessing import image  # Prétraitement d'images pour les modèles Keras
from tensorflow.keras import regularizers  # Outils de régularisation pour les modèles Keras

# %% [markdown]
# # Dataset

# %% [markdown]
# - http://www.lirmm.fr/~poncelet/Ressources/Data_sheep_cat_elephant_with_caption_200.zip
# - http://www.lirmm.fr/~poncelet/Ressources/Data_sheep_cat_elephant_with_caption_400.zip
# - http://www.lirmm.fr/~poncelet/Ressources/Data_sheep_cat_elephant_with_caption_600.zip

# %% [markdown]
# ## Download

# %%
zip_file = "Data_humanface_cat_without_caption_1000.zip"

# Charger les images d'un dossier
data_dir = "./data/dataset/humanface_cat_without_caption_1000/"

os.makedirs('./data/dataset/', exist_ok=True)


#!wget https://www.lirmm.fr/~poncelet/Ressources/cnn_models.zip
# !Powershell.exe -Command ((new-object System.Net.WebClient).DownloadFile('https://www.lirmm.fr/~poncelet/Ressources/Data_humanface_cat_without_caption_1000.zip','Data_humanface_cat_without_caption_1000.zip'))

# Extraction du fichier ZIP
with zipfile.ZipFile(zip_file, "r") as zip_ref:
        zip_ref.extractall(data_dir)

# Suppression du fichier ZIP après extraction pour économiser de l'espace
os.remove(zip_file)

# %% [markdown]
# ## Declare

# %%
batch_size = 32
img_height = 256
img_width = 256



# Charger les images d'un dossier
data_dir = "./data/dataset/humanface_cat_without_caption_1000/images/"
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2000 files belonging to 2 classes.
# Using 1600 files for training.
# Found 2000 files belonging to 2 classes.
# Using 400 files for validation.

# %% [markdown]
# ## Check + Display

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cat', 'man']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 256, 256, 3)
# (64, 2)

# %% [markdown]
# # def

# %% [markdown]
# ## Model

# %%
def define_model(shapeinput=(256, 256, 3)):
    # Définir l'entrée
    inputs = Input(shape=shapeinput, name="Input_Layer")

    # conv
    x = Conv2D(2, (3, 3), activation='relu', name="Conv1_Layer")(inputs)
    x = MaxPooling2D((2, 2), name="Pool1_Layer")(x)
    x = Conv2D(3, (5, 5), activation='relu', name="Conv2_Layer")(x)
    x = MaxPooling2D((2, 2), name="Pool2_Layer")(x)
    x = Conv2D(6, (3, 3), activation='relu', name="Conv3_Layer")(x)
    x = MaxPooling2D((2, 2), name="Pool3_Layer")(x)
    x = Conv2D(8, (3, 3), activation='relu', name="Conv4_Layer")(x)
    x = MaxPooling2D((2, 2), name="Pool4_Layer")(x)
    x = Flatten(name="Flatten_Layer")(x)

    # Partie classification
    x = Dense(15, activation='relu', name="Dense1_Layer")(x)
    x = Dense(10, activation='relu', name="Dense2_Layer")(x)
    x = Dropout(0.2, name="Dropout_Layer")(x)
    outputs = Dense(2, activation='softmax', name="Output_Layer")(x)

    # Construction du modèle
    model = Model(inputs=inputs, outputs=outputs, name="CNN_MC_Model")

    # Compilation
    model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

    return model

# %% [markdown]
# ## eval, dataset, kfold...

# %%
def evaluate_model(model, dataX, dataY, folds=5, epochs=10):
    """
    Évalue le modèle avec une validation croisée K-fold.

    Paramètres :
    - model : modèle de réseau de neurones Keras à évaluer.
    - dataX : données d'entrée pour l'entraînement et la validation.
    - dataY : étiquettes de sortie correspondantes.
    - folds : nombre de splits pour la validation croisée.
    - epochs : nombre d'époques pour l'entraînement de chaque split.

    Retourne :
    - scores : liste des scores d'accuracy du modèle pour chaque split.
    - histories : liste des historique d'entraînement pour chaque split.
    """
    scores, histories = [], []  # Initialisation des scores et historiques
    kfold = KFold(n_splits=folds, shuffle=True, random_state=1)

    # Itération sur chaque split généré par le K-fold
    for train_ix, test_ix in kfold.split(dataX):
        # Sélection des données d'entraînement et de test pour le fold
        X_train, y_train = dataX[train_ix], dataY[train_ix]
        X_test, y_test = dataX[test_ix], dataY[test_ix]

        # Réinitialisation du modèle avant chaque itération
        model = define_model()


        # Entraînement du modèle
        history = model.fit(X_train, y_train, epochs=epochs, batch_size=32,
                            validation_data=(X_test, y_test), verbose=1)

        # Évaluation du modèle sur les données de test actuelles
        loss, acc = model.evaluate(X_test, y_test, verbose=0)
        print(f'Précision : {acc * 100:.3f}%')

        # Stockage de l'historique
        scores.append(acc)
        histories.append(history)

    return scores, histories

# %%
def load_dataset():
    train_ds = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        validation_split=0.3,
        subset="training",
        seed=124,
        image_size=(img_height, img_width),
        batch_size=batch_size,
        label_mode="int",
        shuffle=True,
    )

    val_ds = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        validation_split=0.3,
        subset="validation",
        seed=124,
        image_size=(img_height, img_width),
        batch_size=batch_size,
        label_mode="int",
        shuffle=True,
    )

    X_train_list, y_train_list = [], []
    for x, y in train_ds:
        X_train_list.append(x.numpy())
        y_train_list.append(y.numpy())

    X_test_list, y_test_list = [], []
    for x, y in val_ds:
        X_test_list.append(x.numpy())
        y_test_list.append(y.numpy())

    X_train = np.concatenate(X_train_list, axis=0)
    y_train = np.concatenate(y_train_list, axis=0)
    X_test = np.concatenate(X_test_list, axis=0)
    y_test = np.concatenate(y_test_list, axis=0)

    # One-hot
    numClass = len(train_ds.class_names)
    y_train = to_categorical(y_train, num_classes=numClass)
    y_test = to_categorical(y_test, num_classes=numClass)

    return X_train, y_train, X_test, y_test, train_ds.class_names

# %%
def clean_data(train, test):
    """
    Prétraitement des données : conversion en float, normalisation entre 0 et 1.

    Paramètres :
    - train : tableau de données d'entraînement
    - test : tableau de données de test

    Retourne :
    - train_norm : données d'entraînement normalisées
    - test_norm : données de test normalisées
    """
    # Conversion des entiers en floats pour permettre la normalisation
    train_norm = train.astype('float32')
    test_norm = test.astype('float32')

    # Normalisation des valeurs entre 0 et 1
    train_norm /= 255.0
    test_norm /= 255.0

    return train_norm, test_norm

# %%
def plot_curves(histories):
    """
    Fonction pour afficher les courbes de loss et d'accuracy
    moyennées et écart-types à travers les k-folds.

    Paramètres :
    - histories (list) : Historique d'entraînement des différents plis K-folds.
    """

    # Initialisation des figures
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

    # Extraction du nombre d'époques d'après l'un des historiques
    epochs = range(len(histories[0].history['loss']))

    # Calcul des moyennes et des écart-types pour chaque époque
    mean_loss = np.mean([history.history['loss'] for history in histories],
                        axis=0)
    std_loss = np.std([history.history['loss'] for history in histories],
                      axis=0)

    mean_val_loss = np.mean([history.history['val_loss'] for history in histories],
                            axis=0)
    std_val_loss = np.std([history.history['val_loss'] for history in histories],
                          axis=0)

    mean_accuracy = np.mean([history.history['accuracy'] for history in histories],
                            axis=0)
    std_accuracy = np.std([history.history['accuracy'] for history in histories],
                          axis=0)

    mean_val_accuracy = np.mean([history.history['val_accuracy'] for history in histories],
                                axis=0)
    std_val_accuracy = np.std([history.history['val_accuracy'] for history in histories],
                              axis=0)

    # Couleurs pour les courbes
    train_color = 'blue'
    val_color = 'orange'

    # Courbes de loss avec moyenne et écart-type
    ax1.plot(epochs, mean_loss, color=train_color, label='Train')
    ax1.fill_between(epochs, mean_loss - std_loss, mean_loss + std_loss,
                     color=train_color, alpha=0.2)

    ax1.plot(epochs, mean_val_loss, color=val_color, label='Validation')
    ax1.fill_between(epochs, mean_val_loss - std_val_loss,
                     mean_val_loss + std_val_loss, color=val_color, alpha=0.2)

    # Courbes d'accuracy avec moyenne et écart-type
    ax2.plot(epochs, mean_accuracy, color=train_color, label='Train')
    ax2.fill_between(epochs, mean_accuracy - std_accuracy,
                     mean_accuracy + std_accuracy, color=train_color, alpha=0.2)

    ax2.plot(epochs, mean_val_accuracy, color=val_color, label='Validation')
    ax2.fill_between(epochs, mean_val_accuracy - std_val_accuracy,
                     mean_val_accuracy + std_val_accuracy,
                     color=val_color, alpha=0.2)

    # Titres, labels et légendes
    ax1.set_title(f'Loss (k={len(histories)})')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()

    ax2.set_title(f'Accuracy (k={len(histories)})')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.legend()

    plt.show()

# %%
def run_evaluation(folds, epochs):
    """
    Fonction d'évaluation

    Cette fonction effectue les étapes suivantes :
    1. Chargement du jeu de données Fashion MNIST.
    2. Prétraitement des données : nettoyage et normalisation.
    3. Initialisation du modèle de base et affichage de sa structure.
    4. Évaluation du modèle avec validation croisée (K-fold).
    5. Affichage des courbes de performance et des statistiques de précision.

    Paramètres :
    - folds (int) : Nombre de splits pour la validation croisée (K-fold).
    - epochs (int) : Nombre d'époques d'entraînement pour chaque pli du K-fold.

    Retourne :
    - None
    """

    # Chargement du jeu de données d'entraînement et de test
    X_train, y_train, X_test, y_test, class_names = load_dataset()

    # Prétraitement des données : nettoyage et normalisation
    X_train, X_test = clean_data(X_train, X_test)

    # Initialisation du modèle de base
    model = define_model()
    print(model.summary())

    # Évaluation du modèle
    scores, histories = evaluate_model(model, X_train, y_train, folds, epochs)

    # Affichage des courbes de performance
    plot_curves(histories)

    # Affichage des statistiques de précision : moyenne et écart-type
    print(f'Précision : moyenne={mean(scores) * 100:.3f}% écart-type={std(scores) * 100:.3f}%, k={len(scores)}')

# %% [markdown]
# # run kfold

# %%
k=20 # Nombre de folds
epochs=10 # Nombre d'epochs
shapeinput=(64, 64, 3) # Format de l'image
run_evaluation(k,epochs)
# Out:
# Found 2000 files belonging to 2 classes.
# Using 1400 files for training.
# Found 2000 files belonging to 2 classes.
# Using 600 files for validation.
# Model: "CNN_MC_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input_Layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv1_Layer (Conv2D)            │ (None, 254, 254, 2)    │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool1_Layer (MaxPooling2D)      │ (None, 127, 127, 2)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2_Layer (Conv2D)            │ (None, 123, 123, 3)    │           153 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool2_Layer (MaxPooling2D)      │ (None, 61, 61, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv3_Layer (Conv2D)            │ (None, 59, 59, 6)      │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool3_Layer (MaxPooling2D)      │ (None, 29, 29, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv4_Layer (Conv2D)            │ (None, 27, 27, 8)      │           440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool4_Layer (MaxPooling2D)      │ (None, 13, 13, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten_Layer (Flatten)         │ (None, 1352)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense1_Layer (Dense)            │ (None, 15)             │        20,295 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense2_Layer (Dense)            │ (None, 10)             │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_Layer (Dropout)         │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 2)              │            22 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,294 (83.18 KB)
#  Trainable params: 21,294 (83.18 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6872 - loss: 0.6571 - val_accuracy: 0.9000 - val_loss: 0.4888
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9083 - loss: 0.2602 - val_accuracy: 0.9571 - val_loss: 0.1257
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9586 - loss: 0.1134 - val_accuracy: 0.9714 - val_loss: 0.0614
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9782 - loss: 0.0693 - val_accuracy: 0.9857 - val_loss: 0.0311
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9805 - loss: 0.0522 - val_accuracy: 0.9857 - val_loss: 0.0256
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9880 - loss: 0.0354 - val_accuracy: 0.9857 - val_loss: 0.0275
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9902 - loss: 0.0269 - val_accuracy: 0.9857 - val_loss: 0.0280
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9970 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9940 - loss: 0.0168 - val_accuracy: 0.9857 - val_loss: 0.0319
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9932 - loss: 0.0147 - val_accuracy: 0.9857 - val_loss: 0.0150
# Précision : 98.571%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7722 - loss: 0.5045 - val_accuracy: 0.9286 - val_loss: 0.1977
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9113 - loss: 0.2332 - val_accuracy: 0.9857 - val_loss: 0.0832
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9519 - loss: 0.1528 - val_accuracy: 0.9714 - val_loss: 0.0462
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9541 - loss: 0.1332 - val_accuracy: 0.9857 - val_loss: 0.0563
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9632 - loss: 0.0893 - val_accuracy: 0.9857 - val_loss: 0.0324
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9714 - loss: 0.0674 - val_accuracy: 1.0000 - val_loss: 0.0444
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9684 - loss: 0.0964 - val_accuracy: 0.9286 - val_loss: 0.1050
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9737 - loss: 0.0589 - val_accuracy: 1.0000 - val_loss: 0.0412
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9842 - loss: 0.0468 - val_accuracy: 1.0000 - val_loss: 0.0285
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9827 - loss: 0.0446 - val_accuracy: 1.0000 - val_loss: 0.0161
# Précision : 100.000%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7684 - loss: 0.5138 - val_accuracy: 0.9286 - val_loss: 0.1785
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9421 - loss: 0.1627 - val_accuracy: 0.9714 - val_loss: 0.0774
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9556 - loss: 0.1293 - val_accuracy: 0.9857 - val_loss: 0.0627
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9624 - loss: 0.0967 - val_accuracy: 0.9714 - val_loss: 0.0621
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9729 - loss: 0.0777 - val_accuracy: 0.9857 - val_loss: 0.0357
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9752 - loss: 0.0632 - val_accuracy: 0.9857 - val_loss: 0.0221
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9789 - loss: 0.0610 - val_accuracy: 1.0000 - val_loss: 0.0187
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9729 - loss: 0.0655 - val_accuracy: 0.9714 - val_loss: 0.1165
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9827 - loss: 0.0443 - val_accuracy: 0.9857 - val_loss: 0.0236
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9880 - loss: 0.0345 - val_accuracy: 0.9857 - val_loss: 0.0344
# Précision : 98.571%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7459 - loss: 0.5383 - val_accuracy: 0.8857 - val_loss: 0.2511
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9301 - loss: 0.2233 - val_accuracy: 0.9857 - val_loss: 0.1382
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9617 - loss: 0.1291 - val_accuracy: 0.9429 - val_loss: 0.1106
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9714 - loss: 0.0922 - val_accuracy: 0.9286 - val_loss: 0.1701
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9669 - loss: 0.0901 - val_accuracy: 0.9429 - val_loss: 0.1106
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9789 - loss: 0.0659 - val_accuracy: 0.9857 - val_loss: 0.0633
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9767 - loss: 0.0729 - val_accuracy: 0.9571 - val_loss: 0.1511
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9820 - loss: 0.0532 - val_accuracy: 0.9714 - val_loss: 0.1016
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9842 - loss: 0.0401 - val_accuracy: 0.9571 - val_loss: 0.1918
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9902 - loss: 0.0315 - val_accuracy: 0.9714 - val_loss: 0.0953
# Précision : 97.143%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6429 - loss: 0.6207 - val_accuracy: 0.9143 - val_loss: 0.3859
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8940 - loss: 0.2589 - val_accuracy: 0.9714 - val_loss: 0.1394
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9541 - loss: 0.1470 - val_accuracy: 0.9857 - val_loss: 0.0942
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9692 - loss: 0.1225 - val_accuracy: 0.9857 - val_loss: 0.0872
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9842 - loss: 0.0748 - val_accuracy: 0.9714 - val_loss: 0.0984
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9932 - loss: 0.0333 - val_accuracy: 0.9857 - val_loss: 0.0706
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - loss: 0.0377 - val_accuracy: 0.9857 - val_loss: 0.0932
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9925 - loss: 0.0310 - val_accuracy: 0.9714 - val_loss: 0.1318
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9925 - loss: 0.0295 - val_accuracy: 0.9857 - val_loss: 0.0804
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9970 - loss: 0.0249 - val_accuracy: 0.9857 - val_loss: 0.0842
# Précision : 98.571%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7030 - loss: 0.6426 - val_accuracy: 0.8714 - val_loss: 0.5377
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8850 - loss: 0.3274 - val_accuracy: 0.9143 - val_loss: 0.2095
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9421 - loss: 0.1749 - val_accuracy: 0.9286 - val_loss: 0.1296
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9586 - loss: 0.1101 - val_accuracy: 0.9571 - val_loss: 0.1020
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9541 - loss: 0.1297 - val_accuracy: 0.9429 - val_loss: 0.0847
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9789 - loss: 0.0765 - val_accuracy: 0.9571 - val_loss: 0.0972
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9805 - loss: 0.0686 - val_accuracy: 0.9571 - val_loss: 0.1676
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9842 - loss: 0.0534 - val_accuracy: 0.9571 - val_loss: 0.1161
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9797 - loss: 0.0688 - val_accuracy: 0.9714 - val_loss: 0.0700
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9872 - loss: 0.0497 - val_accuracy: 0.9857 - val_loss: 0.0409
# Précision : 98.571%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6910 - loss: 0.5938 - val_accuracy: 0.9000 - val_loss: 0.3177
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8865 - loss: 0.2943 - val_accuracy: 0.9571 - val_loss: 0.1648
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9504 - loss: 0.1453 - val_accuracy: 0.9143 - val_loss: 0.1598
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9677 - loss: 0.0939 - val_accuracy: 0.9571 - val_loss: 0.1156
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9812 - loss: 0.0690 - val_accuracy: 0.9286 - val_loss: 0.1602
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9789 - loss: 0.0573 - val_accuracy: 0.9714 - val_loss: 0.1204
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9887 - loss: 0.0452 - val_accuracy: 0.9429 - val_loss: 0.1388
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9925 - loss: 0.0327 - val_accuracy: 0.9571 - val_loss: 0.1271
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - loss: 0.0228 - val_accuracy: 0.9714 - val_loss: 0.1202
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9947 - loss: 0.0176 - val_accuracy: 0.9714 - val_loss: 0.1114
# Précision : 97.143%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6038 - loss: 0.6719 - val_accuracy: 0.6000 - val_loss: 0.6014
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8105 - loss: 0.4039 - val_accuracy: 0.9429 - val_loss: 0.1487
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9278 - loss: 0.1927 - val_accuracy: 0.9714 - val_loss: 0.0594
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9398 - loss: 0.1425 - val_accuracy: 0.9857 - val_loss: 0.0687
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9451 - loss: 0.1471 - val_accuracy: 0.9857 - val_loss: 0.0837
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9639 - loss: 0.0987 - val_accuracy: 0.9857 - val_loss: 0.0879
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9654 - loss: 0.0767 - val_accuracy: 0.9714 - val_loss: 0.1096
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9759 - loss: 0.0605 - val_accuracy: 0.9857 - val_loss: 0.0481
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9872 - loss: 0.0445 - val_accuracy: 0.9857 - val_loss: 0.0729
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9797 - loss: 0.0483 - val_accuracy: 0.9857 - val_loss: 0.0425
# Précision : 98.571%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6729 - loss: 0.5619 - val_accuracy: 0.9286 - val_loss: 0.4262
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9045 - loss: 0.3081 - val_accuracy: 0.9571 - val_loss: 0.1417
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9391 - loss: 0.1761 - val_accuracy: 0.9714 - val_loss: 0.0918
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9556 - loss: 0.1395 - val_accuracy: 0.9857 - val_loss: 0.0507
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9692 - loss: 0.1012 - val_accuracy: 1.0000 - val_loss: 0.0310
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9707 - loss: 0.0830 - val_accuracy: 1.0000 - val_loss: 0.0154
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9677 - loss: 0.0887 - val_accuracy: 0.9857 - val_loss: 0.0175
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9805 - loss: 0.0556 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9865 - loss: 0.0550 - val_accuracy: 0.9857 - val_loss: 0.0252
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9835 - loss: 0.0479 - val_accuracy: 1.0000 - val_loss: 0.0040
# Précision : 100.000%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6827 - loss: 0.6029 - val_accuracy: 0.8286 - val_loss: 0.4353
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8737 - loss: 0.3229 - val_accuracy: 0.8857 - val_loss: 0.2778
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8992 - loss: 0.2453 - val_accuracy: 0.9571 - val_loss: 0.1241
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9293 - loss: 0.1858 - val_accuracy: 0.9714 - val_loss: 0.0961
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9481 - loss: 0.1351 - val_accuracy: 0.9714 - val_loss: 0.0764
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9609 - loss: 0.0989 - val_accuracy: 0.9714 - val_loss: 0.0541
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9707 - loss: 0.0669 - val_accuracy: 0.9714 - val_loss: 0.0791
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9782 - loss: 0.0616 - val_accuracy: 0.9714 - val_loss: 0.0599
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9850 - loss: 0.0512 - val_accuracy: 0.9714 - val_loss: 0.0521
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9910 - loss: 0.0426 - val_accuracy: 0.9857 - val_loss: 0.0424
# Précision : 98.571%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5000 - loss: 0.6692 - val_accuracy: 0.6143 - val_loss: 0.5099
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8549 - loss: 0.3445 - val_accuracy: 0.9429 - val_loss: 0.2096
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9429 - loss: 0.2035 - val_accuracy: 0.9571 - val_loss: 0.0942
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9571 - loss: 0.1607 - val_accuracy: 0.9571 - val_loss: 0.0874
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9624 - loss: 0.1134 - val_accuracy: 0.9857 - val_loss: 0.0476
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9684 - loss: 0.1020 - val_accuracy: 0.9571 - val_loss: 0.0645
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9759 - loss: 0.0701 - val_accuracy: 0.9857 - val_loss: 0.0324
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9707 - loss: 0.0881 - val_accuracy: 0.9714 - val_loss: 0.0380
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9759 - loss: 0.0757 - val_accuracy: 0.9714 - val_loss: 0.0469
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9842 - loss: 0.0532 - val_accuracy: 0.9714 - val_loss: 0.0425
# Précision : 97.143%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7180 - loss: 0.5763 - val_accuracy: 0.9000 - val_loss: 0.2553
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9113 - loss: 0.2350 - val_accuracy: 0.9571 - val_loss: 0.1814
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9639 - loss: 0.1281 - val_accuracy: 0.9571 - val_loss: 0.1242
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9759 - loss: 0.0800 - val_accuracy: 0.9714 - val_loss: 0.1347
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9827 - loss: 0.0583 - val_accuracy: 0.9429 - val_loss: 0.1450
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9880 - loss: 0.0399 - val_accuracy: 0.9714 - val_loss: 0.1698
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - loss: 0.0310 - val_accuracy: 0.9571 - val_loss: 0.1778
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - loss: 0.0297 - val_accuracy: 0.9714 - val_loss: 0.1639
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9947 - loss: 0.0190 - val_accuracy: 0.9571 - val_loss: 0.2035
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9902 - loss: 0.0239 - val_accuracy: 0.9714 - val_loss: 0.2008
# Précision : 97.143%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5850 - loss: 0.6857 - val_accuracy: 0.5714 - val_loss: 0.6419
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7842 - loss: 0.4813 - val_accuracy: 0.9286 - val_loss: 0.2001
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9023 - loss: 0.2246 - val_accuracy: 0.9714 - val_loss: 0.0941
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9338 - loss: 0.1434 - val_accuracy: 0.9714 - val_loss: 0.0788
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9594 - loss: 0.1054 - val_accuracy: 0.9571 - val_loss: 0.1528
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9624 - loss: 0.0870 - val_accuracy: 0.9714 - val_loss: 0.0808
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9549 - loss: 0.0792 - val_accuracy: 0.9571 - val_loss: 0.1404
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9654 - loss: 0.0735 - val_accuracy: 0.9714 - val_loss: 0.1542
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9549 - loss: 0.0825 - val_accuracy: 0.9714 - val_loss: 0.0984
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9707 - loss: 0.0493 - val_accuracy: 0.9714 - val_loss: 0.0987
# Précision : 97.143%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6398 - loss: 0.6525 - val_accuracy: 0.8714 - val_loss: 0.5012
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8692 - loss: 0.3144 - val_accuracy: 0.9286 - val_loss: 0.2352
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9203 - loss: 0.2207 - val_accuracy: 0.9571 - val_loss: 0.1654
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9316 - loss: 0.1806 - val_accuracy: 0.9429 - val_loss: 0.1192
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9459 - loss: 0.1603 - val_accuracy: 0.9571 - val_loss: 0.1409
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9346 - loss: 0.1884 - val_accuracy: 0.9714 - val_loss: 0.1129
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9586 - loss: 0.1138 - val_accuracy: 0.9571 - val_loss: 0.0871
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9677 - loss: 0.0735 - val_accuracy: 0.9714 - val_loss: 0.0671
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9677 - loss: 0.0747 - val_accuracy: 0.9571 - val_loss: 0.0728
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9774 - loss: 0.0546 - val_accuracy: 0.9857 - val_loss: 0.0479
# Précision : 98.571%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7120 - loss: 0.6415 - val_accuracy: 0.8714 - val_loss: 0.4247
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8872 - loss: 0.2815 - val_accuracy: 0.9286 - val_loss: 0.2053
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9278 - loss: 0.1865 - val_accuracy: 0.9286 - val_loss: 0.1681
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9444 - loss: 0.1691 - val_accuracy: 0.9571 - val_loss: 0.1360
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9684 - loss: 0.1142 - val_accuracy: 0.9571 - val_loss: 0.1119
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9669 - loss: 0.1060 - val_accuracy: 0.9571 - val_loss: 0.1451
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9789 - loss: 0.0855 - val_accuracy: 0.9429 - val_loss: 0.1214
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9827 - loss: 0.0660 - val_accuracy: 0.9857 - val_loss: 0.0713
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9782 - loss: 0.0728 - val_accuracy: 0.9714 - val_loss: 0.0693
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9865 - loss: 0.0463 - val_accuracy: 0.9857 - val_loss: 0.0506
# Précision : 98.571%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6023 - loss: 0.6141 - val_accuracy: 0.9714 - val_loss: 0.3804
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9135 - loss: 0.2564 - val_accuracy: 0.9571 - val_loss: 0.1641
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9451 - loss: 0.1589 - val_accuracy: 0.9857 - val_loss: 0.0525
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9571 - loss: 0.1265 - val_accuracy: 0.9714 - val_loss: 0.0498
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9669 - loss: 0.0893 - val_accuracy: 0.9857 - val_loss: 0.0427
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9699 - loss: 0.0788 - val_accuracy: 1.0000 - val_loss: 0.0197
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9722 - loss: 0.0753 - val_accuracy: 0.9714 - val_loss: 0.0494
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9842 - loss: 0.0488 - val_accuracy: 0.9714 - val_loss: 0.0762
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9827 - loss: 0.0536 - val_accuracy: 0.9714 - val_loss: 0.0299
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9835 - loss: 0.0430 - val_accuracy: 0.9714 - val_loss: 0.0646
# Précision : 97.143%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6759 - loss: 0.6438 - val_accuracy: 0.9286 - val_loss: 0.4604
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9120 - loss: 0.2445 - val_accuracy: 0.9571 - val_loss: 0.1280
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9579 - loss: 0.1252 - val_accuracy: 0.9857 - val_loss: 0.0812
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9669 - loss: 0.1044 - val_accuracy: 0.9429 - val_loss: 0.1946
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9714 - loss: 0.0889 - val_accuracy: 0.9857 - val_loss: 0.0817
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9744 - loss: 0.0631 - val_accuracy: 0.9857 - val_loss: 0.0717
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9805 - loss: 0.0489 - val_accuracy: 0.9857 - val_loss: 0.0558
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9902 - loss: 0.0342 - val_accuracy: 0.9857 - val_loss: 0.0862
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - loss: 0.0269 - val_accuracy: 0.9857 - val_loss: 0.0869
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9850 - loss: 0.0317 - val_accuracy: 0.9857 - val_loss: 0.0815
# Précision : 98.571%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7120 - loss: 0.5679 - val_accuracy: 0.8143 - val_loss: 0.4486
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8797 - loss: 0.3135 - val_accuracy: 0.9000 - val_loss: 0.2888
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9331 - loss: 0.2111 - val_accuracy: 0.8857 - val_loss: 0.2295
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9391 - loss: 0.1878 - val_accuracy: 0.9286 - val_loss: 0.1370
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9602 - loss: 0.1138 - val_accuracy: 0.9429 - val_loss: 0.1222
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9737 - loss: 0.0935 - val_accuracy: 0.9571 - val_loss: 0.1102
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9767 - loss: 0.0791 - val_accuracy: 0.9429 - val_loss: 0.1084
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9865 - loss: 0.0504 - val_accuracy: 0.9571 - val_loss: 0.1045
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9872 - loss: 0.0475 - val_accuracy: 0.9714 - val_loss: 0.1051
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9887 - loss: 0.0376 - val_accuracy: 0.9429 - val_loss: 0.0887
# Précision : 94.286%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4955 - loss: 0.6723 - val_accuracy: 0.6000 - val_loss: 0.5320
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7744 - loss: 0.4888 - val_accuracy: 0.9286 - val_loss: 0.2538
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8850 - loss: 0.2394 - val_accuracy: 0.9429 - val_loss: 0.1816
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9353 - loss: 0.1661 - val_accuracy: 0.9571 - val_loss: 0.1317
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9519 - loss: 0.1551 - val_accuracy: 0.9714 - val_loss: 0.1054
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9511 - loss: 0.1420 - val_accuracy: 0.9714 - val_loss: 0.0848
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9699 - loss: 0.1227 - val_accuracy: 0.9571 - val_loss: 0.1164
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9632 - loss: 0.1317 - val_accuracy: 0.9714 - val_loss: 0.1007
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9752 - loss: 0.1129 - val_accuracy: 0.9857 - val_loss: 0.0406
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9820 - loss: 0.0874 - val_accuracy: 0.9429 - val_loss: 0.0677
# Précision : 94.286%
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7511 - loss: 0.5879 - val_accuracy: 0.9143 - val_loss: 0.3066
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8812 - loss: 0.3329 - val_accuracy: 0.8857 - val_loss: 0.2447
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9120 - loss: 0.2544 - val_accuracy: 0.9429 - val_loss: 0.1716
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9211 - loss: 0.2132 - val_accuracy: 0.9286 - val_loss: 0.1403
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9331 - loss: 0.1821 - val_accuracy: 0.9429 - val_loss: 0.1692
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9406 - loss: 0.1808 - val_accuracy: 0.9857 - val_loss: 0.0879
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9489 - loss: 0.1388 - val_accuracy: 0.9714 - val_loss: 0.0810
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9609 - loss: 0.1189 - val_accuracy: 0.9571 - val_loss: 0.0675
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9564 - loss: 0.1112 - val_accuracy: 0.9714 - val_loss: 0.0568
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9692 - loss: 0.0894 - val_accuracy: 0.9857 - val_loss: 0.1138
# Précision : 98.571%
# Précision : moyenne=97.857% écart-type=1.464%, k=20

# %% [markdown]
# # train

# %% [markdown]
# ## def

# %%
def train_cnn_model(model, train_ds, val_data, model_path,
                    epochs=10, patience=3, mult_datagen=1):
    """
    Entraîne un modèle CNN avec un générateur de données et des callbacks.

    Args:
        model: Modèle CNN à entraîner.
        train_generator: Générateur d'images pour l'entraînement.
        val_data: Données de validation (X_test, y_test).
        model_path (str): Chemin de sauvegarde du modèle.
        epochs (int): Nombre d'époques d'entraînement.
        patience (int): Patience pour l'arrêt anticipé.
        mult_datagen (int): Facteur de multiplication pour le nombre d'images par époque (augmentation de données).
    Returns:
        Modèle entraîné avec les meilleurs poids restaurés.
    """
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=patience,
                      restore_best_weights=True, verbose=1),
        ModelCheckpoint(model_path, monitor='val_loss',
                        save_best_only=True, verbose=1)
    ]
    base_steps = int(np.ceil(len(X_train) / batch_size))
    steps_per_epoch = mult_datagen * base_steps  # len = ceil(n_samples / batch_size)
    print(f"Image par epoch(avec datagen) : {steps_per_epoch * batch_size}, nb image par batch : {batch_size}")
    model.fit(
        train_ds,
        epochs=epochs,
        steps_per_epoch=steps_per_epoch,
        validation_data=val_data,
        callbacks=callbacks,
        verbose=1
    )

    return model

# Paramètres d'entraînement
epochs = 100
batch_size = 64
model_filename = "CNN2_MC.keras"

# Définition du répertoire cible
model_dir = "./data/models"

# Création du répertoire s'il n'existe pas
os.makedirs(model_dir, exist_ok=True)


model_path = os.path.join(model_dir, model_filename)
# Chemin des images
data_dir = "./data/dataset/humanface_cat_without_caption_1000/images"
# Chargement et normalisation du jeu de données
X_train, y_train, X_test, y_test, class_names = load_dataset()
X_train, X_test = clean_data(X_train, X_test)

# Définition du modèle
model = define_model()
print(model.summary())

AUTOTUNE = tf.data.AUTOTUNE

augment = tf.keras.Sequential(
    [
        tf.keras.layers.RandomTranslation(0.2, 0.2),
        tf.keras.layers.RandomFlip("horizontal"),
    ],
    name="augment",
)

train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.shuffle(buffer_size=len(X_train), reshuffle_each_iteration=True)
train_ds = train_ds.batch(batch_size, drop_remainder=False)
train_ds = train_ds.map(lambda x, y: (augment(x, training=True), y), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.repeat().prefetch(AUTOTUNE)  # <-- repeat()

# Nombre de batchs "normal" pour 1 epoch
base_steps = int(np.ceil(len(X_train) / batch_size))
# Out:
# Found 2000 files belonging to 2 classes.
# Using 1400 files for training.
# Found 2000 files belonging to 2 classes.
# Using 600 files for validation.
# Model: "CNN_MC_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input_Layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv1_Layer (Conv2D)            │ (None, 254, 254, 2)    │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool1_Layer (MaxPooling2D)      │ (None, 127, 127, 2)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2_Layer (Conv2D)            │ (None, 123, 123, 3)    │           153 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool2_Layer (MaxPooling2D)      │ (None, 61, 61, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv3_Layer (Conv2D)            │ (None, 59, 59, 6)      │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool3_Layer (MaxPooling2D)      │ (None, 29, 29, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv4_Layer (Conv2D)            │ (None, 27, 27, 8)      │           440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool4_Layer (MaxPooling2D)      │ (None, 13, 13, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten_Layer (Flatten)         │ (None, 1352)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense1_Layer (Dense)            │ (None, 15)             │        20,295 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense2_Layer (Dense)            │ (None, 10)             │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_Layer (Dropout)         │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 2)              │            22 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,294 (83.18 KB)
#  Trainable params: 21,294 (83.18 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## run

# %%
model = train_cnn_model(model, train_ds,
                          (X_test, y_test), model_path, epochs=epochs, patience=8, mult_datagen=80)
# Out:
# Image par epoch(avec datagen) : 112640, nb image par batch : 64
# Epoch 1/100
# 1758/1760 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8713 - loss: 0.2841
# Epoch 1: val_loss improved from None to 0.05897, saving model to ./data/models\CNN2_MC.keras
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 50s 28ms/step - accuracy: 0.9234 - loss: 0.1903 - val_accuracy: 0.9817 - val_loss: 0.0590
# Epoch 2/100
# 1758/1760 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9642 - loss: 0.0981
# Epoch 2: val_loss did not improve from 0.05897
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 48s 27ms/step - accuracy: 0.9680 - loss: 0.0882 - val_accuracy: 0.9800 - val_loss: 0.0615
# Epoch 3/100
# 1759/1760 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9766 - loss: 0.0641
# Epoch 3: val_loss did not improve from 0.05897
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 50s 28ms/step - accuracy: 0.9789 - loss: 0.0580 - val_accuracy: 0.9800 - val_loss: 0.0602
# Epoch 4/100
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9831 - loss: 0.0479
# Epoch 4: val_loss did not improve from 0.05897
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 53s 30ms/step - accuracy: 0.9844 - loss: 0.0446 - val_accuracy: 0.9767 - val_loss: 0.0693
# Epoch 5/100
# 1759/1760 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9864 - loss: 0.0383
# Epoch 5: val_loss did not improve from 0.05897
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 53s 30ms/step - accuracy: 0.9871 - loss: 0.0360 - val_accuracy: 0.9867 - val_loss: 0.0602
# Epoch 6/100
# 1758/1760 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9888 - loss: 0.0316
# Epoch 6: val_loss did not improve from 0.05897
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 52s 30ms/step - accuracy: 0.9893 - loss: 0.0296 - val_accuracy: 0.9850 - val_loss: 0.0679
# Epoch 7/100
# 1758/1760 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9914 - loss: 0.0240
# Epoch 7: val_loss did not improve from 0.05897
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 51s 29ms/step - accuracy: 0.9915 - loss: 0.0238 - val_accuracy: 0.9817 - val_loss: 0.0632
# Epoch 8/100
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9917 - loss: 0.0233
# Epoch 8: val_loss did not improve from 0.05897
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 48s 27ms/step - accuracy: 0.9923 - loss: 0.0224 - val_accuracy: 0.9783 - val_loss: 0.1121
# Epoch 9/100
# 1758/1760 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9932 - loss: 0.0196
# Epoch 9: val_loss did not improve from 0.05897
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 48s 27ms/step - accuracy: 0.9938 - loss: 0.0185 - val_accuracy: 0.9850 - val_loss: 0.0645
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %% [markdown]
# # Exec

# %% [markdown]
# ## clear alloc

# %%
tf.keras.backend.clear_session()
# Out:
# WARNING:tensorflow:From c:\Users\theen\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %% [markdown]
# ## load

# %%
# Chargement du modèle sauvegardé
model_filename = "CNN2_MC.keras"
model_path = os.path.join(model_dir, model_filename)
model = load_model(model_path)

# %% [markdown]
# ## predict

# %%
numimage = 110
# Prédiction
y_pred = model.predict(X_test[numimage:numimage+25])  # Prédire 25 image
y_pred_labels = np.argmax(y_pred, axis=1)

# Conversion de y_test
y_true_labels = np.argmax(y_test, axis=1)
plt.figure(figsize=(10,15))
columns = 25
for i in range(columns):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_test[i+numimage],cmap=plt.cm.binary)
    plt.xlabel("True label: " + class_names[y_true_labels[i+numimage]] + "\n Predicted: " + class_names[y_pred_labels[i]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %% [markdown]
# ## Confusion

# %%
# Chargement du modèle sauvegardé
model_filename = "CNN2_MC.keras"
model_path = os.path.join(model_dir, model_filename)
model = load_model(model_path)

# Prédiction
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)

# Conversion de y_test
y_true_labels = np.argmax(y_test, axis=1)

# Matrice de confusion
conf = confusion_matrix(y_true_labels, y_pred_labels)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
# Affichage
plt.figure(figsize=(8, 6))
sns.heatmap(conf, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title("Matrice de confusion")
plt.xlabel("Prédictions")
plt.ylabel("Vérité terrain")
plt.tight_layout()
plt.show()

# %% [markdown]
# # analyse

# %% [markdown]
# ## feature extract

# %% [markdown]
# ### choose image

# %%
numimage = 33
plt.figure()
plt.imshow(X_train[numimage])
plt.grid(False)
plt.show()

# Sélection de l'image
my_image = X_train[numimage]

# Extension des dimensions pour manipuler une seule image
my_image = np.expand_dims(my_image, axis=0)

# %% [markdown]
# ### load model

# %%
# Paramètres
epochs = 10
batch_size = 32
model_filename = "CNN2_MC.keras"
model_path = os.path.join(model_dir, model_filename)
model = load_model(model_path)

# %%
# Affichage du nombre de couches
print("Le modèle contient", len(model.layers), "couches.\n")

# Création d'une entrée factice pour initialiser les dimensions
dummy_input = np.zeros((1, img_height, img_width, 3))
_ = model.predict(dummy_input)

# Affichage des noms des couches
print("Noms des couches :")
for name in model.layers:
    print("-", name.name)

# Affichage des dimensions de sortie de chaque couche
print("\nFormats des sorties des différentes couches :")
for i, layer in enumerate(model.layers):
    output_shape = layer.output.shape
    print(f"Layer [{i}] : {layer.name}, shape de sortie : {output_shape}")
# Out:
# Le modèle contient 14 couches.
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Noms des couches :
# - Input_Layer
# - Conv1_Layer
# - Pool1_Layer
# - Conv2_Layer
# - Pool2_Layer
# - Conv3_Layer
# - Pool3_Layer
# - Conv4_Layer
# - Pool4_Layer
# - Flatten_Layer
# - Dense1_Layer
# - Dense2_Layer
# - Dropout_Layer
# - Output_Layer
#
# Formats des sorties des différentes couches :
# Layer [0] : Input_Layer, shape de sortie : (None, 256, 256, 3)
# Layer [1] : Conv1_Layer, shape de sortie : (None, 254, 254, 2)
# Layer [2] : Pool1_Layer, shape de sortie : (None, 127, 127, 2)
# Layer [3] : Conv2_Layer, shape de sortie : (None, 123, 123, 3)
# Layer [4] : Pool2_Layer, shape de sortie : (None, 61, 61, 3)
# Layer [5] : Conv3_Layer, shape de sortie : (None, 59, 59, 6)
# Layer [6] : Pool3_Layer, shape de sortie : (None, 29, 29, 6)
# Layer [7] : Conv4_Layer, shape de sortie : (None, 27, 27, 8)
# Layer [8] : Pool4_Layer, shape de sortie : (None, 13, 13, 8)
# Layer [9] : Flatten_Layer, shape de sortie : (None, 1352)
# Layer [10] : Dense1_Layer, shape de sortie : (None, 15)
# Layer [11] : Dense2_Layer, shape de sortie : (None, 10)
# Layer [12] : Dropout_Layer, shape de sortie : (None, 10)
# Layer [13] : Output_Layer, shape de sortie : (None, 2)

# %% [markdown]
# ### Only first

# %% [markdown]
# #### extract first

# %%
 # Création d’un modèle pour extraire les feature maps de la première couche de convolution
feature_map_layer1 = tf.keras.models.Model(
    inputs=model.input,                     # Entrée d'origine du modèle
    outputs=model.get_layer("Conv1_Layer").output  # Sortie de la couche nommée "Conv1_Layer"
)

# %% [markdown]
# #### predict

# %%
features=feature_map_layer1.predict(my_image)
print (features.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# (1, 254, 254, 2)

# %% [markdown]
# #### plot

# %%
fig = plt.figure(figsize=(20, 15))

# Afficher chaque feature map
for i in range(1, features.shape[3] + 1):
    ax = plt.subplot(8, 8, i)
    ax.imshow(features[0, :, :, i - 1], cmap='gray')
    ax.axis('off')
    ax.set_title(f'Feature Map {i}')

# Afficher toutes les feature maps
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Several

# %% [markdown]
# #### Extract

# %%
# Noms des couches de convolution à visualiser
list_layer_conv = ["Conv1_Layer", "Conv2_Layer", "Conv3_Layer", "Conv4_Layer"]

# Récupération des sorties de ces couches
outputs = [model.get_layer(name).output for name in list_layer_conv]

# Création d’un modèle intermédiaire pour extraire les activations
feature_maps_model = tf.keras.models.Model(inputs=model.input, outputs=outputs)

# Prédiction des feature maps pour une image donnée 
feature_maps = feature_maps_model.predict(my_image)
# Out:
# WARNING:tensorflow:5 out of the last 22 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000025D91FA8670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %% [markdown]
# #### display

# %%
# Affichage des feature maps pour chaque couche de convolution sélectionnée
for layer_name, fmap in zip(list_layer_conv, feature_maps):
    # Création d'une figure pour la couche en cours
    fig = plt.figure(figsize=(15, 10))
    fig.suptitle(layer_name, fontsize=20)

    num_feature_maps = fmap.shape[-1]  # Nombre de cartes d’activation
    cols = 3 if num_feature_maps == 6 else 8  # Nombre de colonnes
    rows = (num_feature_maps // cols) + (num_feature_maps % cols > 0)

    for j in range(num_feature_maps):
        plt.subplot(rows, cols, j + 1)
        plt.imshow(fmap[0, :, :, j], cmap='gray')
        plt.axis('off')

    plt.tight_layout()
    plt.show()
